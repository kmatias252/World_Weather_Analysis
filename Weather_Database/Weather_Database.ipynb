# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | esperance
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | manzhouli
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | nanortalik
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | dingle
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | bengkulu
# Processing Record 13 of Set 1 | kaduy
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | kidal
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | la dorada
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | vega de alatorre
# Processing Record 22 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 1 | langsa
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | camaguey
# Processing Record 30 of Set 1 | campo maior
# Processing Record 31 of Set 1 | tyristrand
# Processing Record 32 of Set 1 | manthani
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | turukhansk
# Processing Record 35 of Set 1 | matamoros
# Processing Record 36 of Set 1 | paamiut
# Processing Record 37 of Set 1 | veraval
# Processing Record 38 of Set 1 | rabo de peixe
# Processing Record 39 of Set 1 | biak
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | islamkot
# Processing Record 42 of Set 1 | lesnyye polyany
# Processing Record 43 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 1 | camacha
# Processing Record 45 of Set 1 | moussoro
# Processing Record 46 of Set 1 | languyan
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | ginda
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | brae
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | utica
# Processing Record 7 of Set 2 | aitape
# Processing Record 8 of Set 2 | quatre cocos
# Processing Record 9 of Set 2 | zhangjiakou
# Processing Record 10 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 2 | broome
# Processing Record 12 of Set 2 | colomi
# Processing Record 13 of Set 2 | uruacu
# Processing Record 14 of Set 2 | leningradskiy
# Processing Record 15 of Set 2 | codrington
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | palembang
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | premnitz
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | leeton
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | prince rupert
# Processing Record 26 of Set 2 | sibolga
# Processing Record 27 of Set 2 | guanica
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | laguna
# Processing Record 30 of Set 2 | kilindoni
# Processing Record 31 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 2 | sur
# Processing Record 33 of Set 2 | gornopravdinsk
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | pisco
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | pontal do parana
# Processing Record 43 of Set 2 | yara
# Processing Record 44 of Set 2 | lafia
# Processing Record 45 of Set 2 | yatou
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | dong hoi
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | port hardy
# Processing Record 50 of Set 2 | eureka
# Processing Record 1 of Set 3 | korla
# Processing Record 2 of Set 3 | zhigansk
# Processing Record 3 of Set 3 | namibe
# Processing Record 4 of Set 3 | boone
# Processing Record 5 of Set 3 | balao
# Processing Record 6 of Set 3 | pokhara
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | yining
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | ilulissat
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | road town
# Processing Record 15 of Set 3 | vila velha
# Processing Record 16 of Set 3 | kobojango
# City not found. Skipping...
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | petrolina de goias
# Processing Record 19 of Set 3 | vestmannaeyjar
# Processing Record 20 of Set 3 | grants
# Processing Record 21 of Set 3 | vitim
# Processing Record 22 of Set 3 | charters towers
# Processing Record 23 of Set 3 | nantucket
# Processing Record 24 of Set 3 | zhezkazgan
# Processing Record 25 of Set 3 | leh
# Processing Record 26 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 3 | mitsamiouli
# Processing Record 28 of Set 3 | ponta delgada
# Processing Record 29 of Set 3 | bonavista
# Processing Record 30 of Set 3 | karratha
# Processing Record 31 of Set 3 | gazanjyk
# Processing Record 32 of Set 3 | vila franca do campo
# Processing Record 33 of Set 3 | qaanaaq
# Processing Record 34 of Set 3 | padang
# Processing Record 35 of Set 3 | dzaoudzi
# Processing Record 36 of Set 3 | manggar
# Processing Record 37 of Set 3 | launceston
# Processing Record 38 of Set 3 | cap malheureux
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | airai
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | sioux lookout
# Processing Record 43 of Set 3 | te anau
# Processing Record 44 of Set 3 | port macquarie
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 50 of Set 3 | tiksi
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | komsomolskiy
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | labuhan
# Processing Record 5 of Set 4 | gorodishche
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | talnakh
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | mabaruma
# Processing Record 11 of Set 4 | bonfim
# Processing Record 12 of Set 4 | santiago del estero
# Processing Record 13 of Set 4 | aklavik
# Processing Record 14 of Set 4 | provost
# Processing Record 15 of Set 4 | riyadh
# Processing Record 16 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 4 | derzhavinsk
# Processing Record 18 of Set 4 | torbay
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | kuah
# Processing Record 21 of Set 4 | makakilo city
# Processing Record 22 of Set 4 | cockburn town
# Processing Record 23 of Set 4 | hof
# Processing Record 24 of Set 4 | mwinilunga
# Processing Record 25 of Set 4 | katsuura
# Processing Record 26 of Set 4 | vostok
# Processing Record 27 of Set 4 | boguchany
# Processing Record 28 of Set 4 | orocue
# Processing Record 29 of Set 4 | torbat-e jam
# Processing Record 30 of Set 4 | husavik
# Processing Record 31 of Set 4 | mzimba
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | ankpa
# Processing Record 35 of Set 4 | kalevala
# Processing Record 36 of Set 4 | yulara
# Processing Record 37 of Set 4 | waipawa
# Processing Record 38 of Set 4 | rivadavia
# Processing Record 39 of Set 4 | price
# Processing Record 40 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 4 | zambezi
# Processing Record 43 of Set 4 | araouane
# Processing Record 44 of Set 4 | tambopata
# Processing Record 45 of Set 4 | anito
# Processing Record 46 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 4 | belaya gora
# Processing Record 48 of Set 4 | talara
# Processing Record 49 of Set 4 | iquitos
# Processing Record 50 of Set 4 | ugoofaaru
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | strezhevoy
# Processing Record 3 of Set 5 | ahipara
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | cherskiy
# Processing Record 6 of Set 5 | port lincoln
# Processing Record 7 of Set 5 | kashi
# Processing Record 8 of Set 5 | marzuq
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | atherton
# Processing Record 11 of Set 5 | saint-jovite
# Processing Record 12 of Set 5 | chimoio
# Processing Record 13 of Set 5 | agirish
# Processing Record 14 of Set 5 | san luis
# Processing Record 15 of Set 5 | ambilobe
# Processing Record 16 of Set 5 | carutapera
# Processing Record 17 of Set 5 | ketchikan
# Processing Record 18 of Set 5 | sepolno krajenskie
# Processing Record 19 of Set 5 | inirida
# Processing Record 20 of Set 5 | nome
# Processing Record 21 of Set 5 | los llanos de aridane
# Processing Record 22 of Set 5 | vagay
# Processing Record 23 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 5 | kavaratti
# Processing Record 25 of Set 5 | lavrentiya
# Processing Record 26 of Set 5 | faya
# Processing Record 27 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 28 of Set 5 | butwal
# Processing Record 29 of Set 5 | souillac
# Processing Record 30 of Set 5 | lorengau
# Processing Record 31 of Set 5 | upernavik
# Processing Record 32 of Set 5 | jalu
# Processing Record 33 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 5 | hurghada
# Processing Record 35 of Set 5 | port-gentil
# Processing Record 36 of Set 5 | idrija
# Processing Record 37 of Set 5 | cabo san lucas
# Processing Record 38 of Set 5 | lasa
# Processing Record 39 of Set 5 | lobito
# Processing Record 40 of Set 5 | shiyan
# Processing Record 41 of Set 5 | georgiyevka
# Processing Record 42 of Set 5 | bairnsdale
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | bredasdorp
# Processing Record 45 of Set 5 | porto novo
# Processing Record 46 of Set 5 | nadbai
# Processing Record 47 of Set 5 | koutsouras
# Processing Record 48 of Set 5 | kesennuma
# City not found. Skipping...
# Processing Record 49 of Set 5 | muslyumovo
# Processing Record 50 of Set 5 | monterey
# Processing Record 1 of Set 6 | yerbogachen
# Processing Record 2 of Set 6 | severnyy
# Processing Record 3 of Set 6 | vardo
# Processing Record 4 of Set 6 | itoman
# Processing Record 5 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 6 of Set 6 | tabas
# Processing Record 7 of Set 6 | galle
# Processing Record 8 of Set 6 | capitan bado
# Processing Record 9 of Set 6 | kununurra
# Processing Record 10 of Set 6 | kolpashevo
# Processing Record 11 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 6 | hambantota
# Processing Record 13 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 6 | arraial do cabo
# Processing Record 15 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 6 | borogontsy
# Processing Record 17 of Set 6 | lagoa
# Processing Record 18 of Set 6 | nkhata bay
# Processing Record 19 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 20 of Set 6 | longyearbyen
# Processing Record 21 of Set 6 | abha
# Processing Record 22 of Set 6 | grand gaube
# Processing Record 23 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 24 of Set 6 | waupun
# Processing Record 25 of Set 6 | ostrovnoy
# Processing Record 26 of Set 6 | kutum
# Processing Record 27 of Set 6 | macas
# Processing Record 28 of Set 6 | kloulklubed
# Processing Record 29 of Set 6 | kieta
# Processing Record 30 of Set 6 | poum
# Processing Record 31 of Set 6 | cururupu
# Processing Record 32 of Set 6 | ekibastuz
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | tazovskiy
# Processing Record 35 of Set 6 | bilma
# Processing Record 36 of Set 6 | majene
# Processing Record 37 of Set 6 | honningsvag
# Processing Record 38 of Set 6 | kimbe
# Processing Record 39 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 40 of Set 6 | svetlogorsk
# Processing Record 41 of Set 6 | ygatimi
# Processing Record 42 of Set 6 | kushiro
# Processing Record 43 of Set 6 | moron
# Processing Record 44 of Set 6 | astana
# Processing Record 45 of Set 6 | binzhou
# Processing Record 46 of Set 6 | sao filipe
# Processing Record 47 of Set 6 | westport
# Processing Record 48 of Set 6 | collie
# Processing Record 49 of Set 6 | touros
# Processing Record 50 of Set 6 | shelburne
# Processing Record 1 of Set 7 | smolyaninovo
# Processing Record 2 of Set 7 | tianpeng
# Processing Record 3 of Set 7 | kalmunai
# Processing Record 4 of Set 7 | maturin
# Processing Record 5 of Set 7 | ulladulla
# Processing Record 6 of Set 7 | trogir
# Processing Record 7 of Set 7 | bafoulabe
# Processing Record 8 of Set 7 | georgetown
# Processing Record 9 of Set 7 | crotone
# Processing Record 10 of Set 7 | margate
# Processing Record 11 of Set 7 | ritchie
# Processing Record 12 of Set 7 | kosa
# Processing Record 13 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 14 of Set 7 | hofn
# Processing Record 15 of Set 7 | sona
# Processing Record 16 of Set 7 | aanekoski
# Processing Record 17 of Set 7 | saryg-sep
# Processing Record 18 of Set 7 | chara
# Processing Record 19 of Set 7 | itaguacu
# Processing Record 20 of Set 7 | tres arroyos
# Processing Record 21 of Set 7 | cidreira
# Processing Record 22 of Set 7 | san cristobal
# Processing Record 23 of Set 7 | deputatskiy
# Processing Record 24 of Set 7 | mount darwin
# Processing Record 25 of Set 7 | miles city
# Processing Record 26 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 7 | machalpur
# Processing Record 28 of Set 7 | penzance
# Processing Record 29 of Set 7 | camabatela
# Processing Record 30 of Set 7 | liverpool
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | bodden town
# Processing Record 33 of Set 7 | ampanihy
# Processing Record 34 of Set 7 | santa catarina de tepehuanes
# Processing Record 35 of Set 7 | whitianga
# Processing Record 36 of Set 7 | methven
# Processing Record 37 of Set 7 | half moon bay
# Processing Record 38 of Set 7 | lazaro cardenas
# Processing Record 39 of Set 7 | nokaneng
# Processing Record 40 of Set 7 | gilbues
# Processing Record 41 of Set 7 | goderich
# Processing Record 42 of Set 7 | zyryanka
# Processing Record 43 of Set 7 | safaga
# Processing Record 44 of Set 7 | salisbury
# Processing Record 45 of Set 7 | port hawkesbury
# Processing Record 46 of Set 7 | cayenne
# Processing Record 47 of Set 7 | hasaki
# Processing Record 48 of Set 7 | korem
# Processing Record 49 of Set 7 | yablonovo
# Processing Record 50 of Set 7 | sadove
# Processing Record 1 of Set 8 | shenjiamen
# Processing Record 2 of Set 8 | basco
# Processing Record 3 of Set 8 | black river
# Processing Record 4 of Set 8 | pacific grove
# Processing Record 5 of Set 8 | acaponeta
# Processing Record 6 of Set 8 | mount gambier
# Processing Record 7 of Set 8 | asilah
# Processing Record 8 of Set 8 | naze
# Processing Record 9 of Set 8 | watsa
# Processing Record 10 of Set 8 | fort nelson
# Processing Record 11 of Set 8 | puerto colombia
# Processing Record 12 of Set 8 | thilogne
# City not found. Skipping...
# Processing Record 13 of Set 8 | wajima
# Processing Record 14 of Set 8 | ambunti
# Processing Record 15 of Set 8 | sorland
# Processing Record 16 of Set 8 | awjilah
# Processing Record 17 of Set 8 | soyo
# Processing Record 18 of Set 8 | new glasgow
# Processing Record 19 of Set 8 | qujing
# Processing Record 20 of Set 8 | honiara
# Processing Record 21 of Set 8 | grazhdanskoye pervoye
# City not found. Skipping...
# Processing Record 22 of Set 8 | ixtapa
# Processing Record 23 of Set 8 | kisangani
# Processing Record 24 of Set 8 | bani
# Processing Record 25 of Set 8 | borovoy
# Processing Record 26 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 8 | ola
# Processing Record 29 of Set 8 | junin
# Processing Record 30 of Set 8 | balkhash
# Processing Record 31 of Set 8 | pangnirtung
# Processing Record 32 of Set 8 | iskateley
# Processing Record 33 of Set 8 | bintulu
# Processing Record 34 of Set 8 | yukamenskoye
# Processing Record 35 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 8 | faanui
# Processing Record 37 of Set 8 | zhoucheng
# Processing Record 38 of Set 8 | kot kapura
# Processing Record 39 of Set 8 | ancud
# Processing Record 40 of Set 8 | carthage
# Processing Record 41 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 42 of Set 8 | pochutla
# Processing Record 43 of Set 8 | providencia
# Processing Record 44 of Set 8 | sinnamary
# Processing Record 45 of Set 8 | palmer
# Processing Record 46 of Set 8 | san carlos de bariloche
# Processing Record 47 of Set 8 | fortuna
# Processing Record 48 of Set 8 | merauke
# Processing Record 49 of Set 8 | lysyye gory
# Processing Record 50 of Set 8 | katobu
# Processing Record 1 of Set 9 | klaksvik
# Processing Record 2 of Set 9 | viedma
# Processing Record 3 of Set 9 | chandbali
# Processing Record 4 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 9 | santa maria
# Processing Record 6 of Set 9 | gilgil
# City not found. Skipping...
# Processing Record 7 of Set 9 | vestmanna
# Processing Record 8 of Set 9 | mayahi
# Processing Record 9 of Set 9 | lulea
# Processing Record 10 of Set 9 | aras
# Processing Record 11 of Set 9 | taltal
# Processing Record 12 of Set 9 | nara
# Processing Record 13 of Set 9 | aksu
# Processing Record 14 of Set 9 | cabinda
# Processing Record 15 of Set 9 | sikonge
# Processing Record 16 of Set 9 | ukiah
# Processing Record 17 of Set 9 | dodge city
# Processing Record 18 of Set 9 | sebrovo
# Processing Record 19 of Set 9 | sipe sipe
# Processing Record 20 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 9 | lubao
# Processing Record 22 of Set 9 | methoni
# Processing Record 23 of Set 9 | chernyshevskiy
# Processing Record 24 of Set 9 | sistranda
# Processing Record 25 of Set 9 | daru
# Processing Record 26 of Set 9 | esso
# Processing Record 27 of Set 9 | grafton
# Processing Record 28 of Set 9 | petrozavodsk
# Processing Record 29 of Set 9 | itarema
# Processing Record 30 of Set 9 | samarai
# Processing Record 31 of Set 9 | porto de moz
# Processing Record 32 of Set 9 | surgut
# Processing Record 33 of Set 9 | abhar
# Processing Record 34 of Set 9 | rosetown
# Processing Record 35 of Set 9 | mumford
# Processing Record 36 of Set 9 | bahia honda
# Processing Record 37 of Set 9 | ponta do sol
# Processing Record 38 of Set 9 | massa marittima
# Processing Record 39 of Set 9 | la asuncion
# Processing Record 40 of Set 9 | novo aripuana
# Processing Record 41 of Set 9 | oranjestad
# Processing Record 42 of Set 9 | ausa
# Processing Record 43 of Set 9 | laizhou
# Processing Record 44 of Set 9 | nelson bay
# Processing Record 45 of Set 9 | flin flon
# Processing Record 46 of Set 9 | saint anthony
# Processing Record 47 of Set 9 | byron bay
# Processing Record 48 of Set 9 | hirado
# Processing Record 49 of Set 9 | harper
# Processing Record 50 of Set 9 | altagracia de orituco
# Processing Record 1 of Set 10 | cheremukhovo
# Processing Record 2 of Set 10 | esna
# Processing Record 3 of Set 10 | tura
# Processing Record 4 of Set 10 | sydney mines
# Processing Record 5 of Set 10 | kiruna
# Processing Record 6 of Set 10 | alta floresta
# Processing Record 7 of Set 10 | cornwall
# Processing Record 8 of Set 10 | ordu
# Processing Record 9 of Set 10 | grindavik
# Processing Record 10 of Set 10 | anadyr
# Processing Record 11 of Set 10 | ingham
# Processing Record 12 of Set 10 | sakakah
# Processing Record 13 of Set 10 | gazli
# Processing Record 14 of Set 10 | seoul
# Processing Record 15 of Set 10 | okha
# Processing Record 16 of Set 10 | baherden
# Processing Record 17 of Set 10 | joshimath
# Processing Record 18 of Set 10 | bansdih
# Processing Record 19 of Set 10 | port-cartier
# Processing Record 20 of Set 10 | barra do garcas
# Processing Record 21 of Set 10 | pierre
# Processing Record 22 of Set 10 | indramayu
# Processing Record 23 of Set 10 | amapa
# Processing Record 24 of Set 10 | mahibadhoo
# Processing Record 25 of Set 10 | vilhena
# Processing Record 26 of Set 10 | gasa
# Processing Record 27 of Set 10 | san vicente
# Processing Record 28 of Set 10 | voh
# Processing Record 29 of Set 10 | lata
# Processing Record 30 of Set 10 | nishihara
# Processing Record 31 of Set 10 | cervo
# Processing Record 32 of Set 10 | zaporizhzhya
# Processing Record 33 of Set 10 | laem sing
# Processing Record 34 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 35 of Set 10 | baruun-urt
# Processing Record 36 of Set 10 | bonthe
# Processing Record 37 of Set 10 | barcelos
# Processing Record 38 of Set 10 | tete
# Processing Record 39 of Set 10 | moindou
# Processing Record 40 of Set 10 | labuan
# Processing Record 41 of Set 10 | tromso
# Processing Record 42 of Set 10 | lithakia
# Processing Record 43 of Set 10 | xianyang
# Processing Record 44 of Set 10 | tierranueva
# Processing Record 45 of Set 10 | dobryanka
# Processing Record 46 of Set 10 | quthing
# Processing Record 47 of Set 10 | kinablangan
# Processing Record 48 of Set 10 | masvingo
# Processing Record 49 of Set 10 | peruibe
# Processing Record 50 of Set 10 | necochea
# Processing Record 1 of Set 11 | jizan
# Processing Record 2 of Set 11 | lewisporte
# Processing Record 3 of Set 11 | polunochnoye
# Processing Record 4 of Set 11 | asau
# Processing Record 5 of Set 11 | yerkoy
# Processing Record 6 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 11 | isangel
# Processing Record 8 of Set 11 | erenhot
# Processing Record 9 of Set 11 | mandiana
# Processing Record 10 of Set 11 | burnie
# Processing Record 11 of Set 11 | consolacion del sur
# Processing Record 12 of Set 11 | isiolo
# Processing Record 13 of Set 11 | waverly
# Processing Record 14 of Set 11 | narsaq
# Processing Record 15 of Set 11 | andros town
# Processing Record 16 of Set 11 | altay
# Processing Record 17 of Set 11 | coihaique
# Processing Record 18 of Set 11 | fasa
# Processing Record 19 of Set 11 | marfino
# Processing Record 20 of Set 11 | ludvika
# Processing Record 21 of Set 11 | pokanayevka
# City not found. Skipping...
# Processing Record 22 of Set 11 | otradnoye
# Processing Record 23 of Set 11 | wasilla
# Processing Record 24 of Set 11 | omboue
# Processing Record 25 of Set 11 | jumla
# Processing Record 26 of Set 11 | gamba
# Processing Record 27 of Set 11 | saint george
# Processing Record 28 of Set 11 | tilichiki
# Processing Record 29 of Set 11 | hay river
# Processing Record 30 of Set 11 | tokol
# City not found. Skipping...
# Processing Record 31 of Set 11 | dorokhovo
# Processing Record 32 of Set 11 | qui nhon
# Processing Record 33 of Set 11 | bani walid
# Processing Record 34 of Set 11 | saint-augustin
# Processing Record 35 of Set 11 | belyy yar
# Processing Record 36 of Set 11 | kruisfontein
# Processing Record 37 of Set 11 | limon
# Processing Record 38 of Set 11 | outjo
# Processing Record 39 of Set 11 | sabang
# Processing Record 40 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 11 | usinsk
# Processing Record 42 of Set 11 | vao
# Processing Record 43 of Set 11 | rawson
# Processing Record 44 of Set 11 | alamosa
# Processing Record 45 of Set 11 | noumea
# Processing Record 46 of Set 11 | najran
# Processing Record 47 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 11 | zarubino
# Processing Record 49 of Set 11 | qaqortoq
# Processing Record 50 of Set 11 | sao joao da barra
# Processing Record 1 of Set 12 | sulangan
# Processing Record 2 of Set 12 | general roca
# Processing Record 3 of Set 12 | zhigalovo
# Processing Record 4 of Set 12 | atar
# Processing Record 5 of Set 12 | key west
# Processing Record 6 of Set 12 | inta
# Processing Record 7 of Set 12 | gashua
# Processing Record 8 of Set 12 | antalaha
# Processing Record 9 of Set 12 | college
# Processing Record 10 of Set 12 | avera
# Processing Record 11 of Set 12 | bambari
# Processing Record 12 of Set 12 | la ronge
# Processing Record 13 of Set 12 | artvin
# Processing Record 14 of Set 12 | turayf
# Processing Record 15 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 12 | balkanabat
# Processing Record 17 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 12 | shu
# Processing Record 19 of Set 12 | kendal
# Processing Record 20 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 12 | kahului
# Processing Record 22 of Set 12 | matay
# Processing Record 23 of Set 12 | itupiranga
# Processing Record 24 of Set 12 | pithoro
# Processing Record 25 of Set 12 | lalsk
# Processing Record 26 of Set 12 | sola
# Processing Record 27 of Set 12 | san juan del sur
# Processing Record 28 of Set 12 | peniche
# Processing Record 29 of Set 12 | san patricio
# Processing Record 30 of Set 12 | manzanillo
# Processing Record 31 of Set 12 | tuatapere
# Processing Record 32 of Set 12 | potsdam
# Processing Record 33 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 34 of Set 12 | richards bay
# Processing Record 35 of Set 12 | ormara
# Processing Record 36 of Set 12 | novyy rogachik
# Processing Record 37 of Set 12 | stephenville
# Processing Record 38 of Set 12 | urumita
# Processing Record 39 of Set 12 | paciran
# Processing Record 40 of Set 12 | tchaourou
# Processing Record 41 of Set 12 | aksarka
# Processing Record 42 of Set 12 | maceio
# Processing Record 43 of Set 12 | santa isabel do rio negro
# Processing Record 44 of Set 12 | leshukonskoye
# Processing Record 45 of Set 12 | mehriz
# Processing Record 46 of Set 12 | kankon
# Processing Record 47 of Set 12 | igarka
# Processing Record 48 of Set 12 | fort morgan
# Processing Record 49 of Set 12 | ubajara
# Processing Record 50 of Set 12 | suzun
# Processing Record 1 of Set 13 | warrnambool
# Processing Record 2 of Set 13 | sept-iles
# Processing Record 3 of Set 13 | san vicente de canete
# Processing Record 4 of Set 13 | nyiradony
# Processing Record 5 of Set 13 | haines junction
# Processing Record 6 of Set 13 | hualmay
# Processing Record 7 of Set 13 | adrar
# Processing Record 8 of Set 13 | mogadishu
# Processing Record 9 of Set 13 | verkhniy avzyan
# Processing Record 10 of Set 13 | ambon
# Processing Record 11 of Set 13 | uyuni
# Processing Record 12 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 13 | valparaiso
# Processing Record 14 of Set 13 | wum
# Processing Record 15 of Set 13 | kathmandu
# Processing Record 16 of Set 13 | north bend
# Processing Record 17 of Set 13 | sembakung
# Processing Record 18 of Set 13 | trzebiatow
# Processing Record 19 of Set 13 | raudeberg
# Processing Record 20 of Set 13 | tsogni
# Processing Record 21 of Set 13 | atambua
# Processing Record 22 of Set 13 | nemuro
# Processing Record 23 of Set 13 | kuopio
# Processing Record 24 of Set 13 | miraflores
# Processing Record 25 of Set 13 | romny
# Processing Record 26 of Set 13 | mildura
# Processing Record 27 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 13 | pondicherry
# Processing Record 29 of Set 13 | khandbari
# Processing Record 30 of Set 13 | kuzino
# Processing Record 31 of Set 13 | moose factory
# Processing Record 32 of Set 13 | bembereke
# Processing Record 33 of Set 13 | jiangyou
# Processing Record 34 of Set 13 | sobolevo
# Processing Record 35 of Set 13 | kevsala
# Processing Record 36 of Set 13 | imbituva
# Processing Record 37 of Set 13 | port pirie
# Processing Record 38 of Set 13 | mbalmayo
# Processing Record 39 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 13 | iralaya
# Processing Record 41 of Set 13 | flinders
# Processing Record 42 of Set 13 | ojinaga
# Processing Record 43 of Set 13 | san andres
# Processing Record 44 of Set 13 | cotonou
# Processing Record 45 of Set 13 | zdvinsk
# Processing Record 46 of Set 13 | fairview
# Processing Record 47 of Set 13 | saurimo
# Processing Record 48 of Set 13 | bathsheba
# Processing Record 49 of Set 13 | bud
# Processing Record 50 of Set 13 | parati
# Processing Record 1 of Set 14 | caravelas
# Processing Record 2 of Set 14 | babati
# Processing Record 3 of Set 14 | carolina
# Processing Record 4 of Set 14 | gonbad-e qabus
# Processing Record 5 of Set 14 | san quintin
# Processing Record 6 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 14 | puerto escondido
# Processing Record 8 of Set 14 | praia
# Processing Record 9 of Set 14 | zeya
# Processing Record 10 of Set 14 | rebrikha
# Processing Record 11 of Set 14 | punta de bombon
# Processing Record 12 of Set 14 | porto walter
# Processing Record 13 of Set 14 | salta
# Processing Record 14 of Set 14 | tinde
# Processing Record 15 of Set 14 | mochudi
# Processing Record 16 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 14 | sabha
# Processing Record 18 of Set 14 | mokolo
# Processing Record 19 of Set 14 | kirakira
# Processing Record 20 of Set 14 | okahandja
# Processing Record 21 of Set 14 | banff
# Processing Record 22 of Set 14 | tessalit
# Processing Record 23 of Set 14 | rio gallegos
# Processing Record 24 of Set 14 | yuancheng
# Processing Record 25 of Set 14 | ranong
# Processing Record 26 of Set 14 | miri
# Processing Record 27 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 14 | bratsk
# Processing Record 29 of Set 14 | abu dhabi
# Processing Record 30 of Set 14 | iqaluit
# Processing Record 31 of Set 14 | rocha
# Processing Record 32 of Set 14 | kikerino
# Processing Record 33 of Set 14 | maningrida
# Processing Record 34 of Set 14 | praia da vitoria
# Processing Record 35 of Set 14 | port blair
# Processing Record 36 of Set 14 | bereda
# Processing Record 37 of Set 14 | selma
# Processing Record 38 of Set 14 | kalianget
# Processing Record 39 of Set 14 | mana
# Processing Record 40 of Set 14 | dostat
# Processing Record 41 of Set 14 | dharchula
# Processing Record 42 of Set 14 | hamilton
# Processing Record 43 of Set 14 | floro
# Processing Record 44 of Set 14 | pontiac
# Processing Record 45 of Set 14 | fulitun
# City not found. Skipping...
# Processing Record 46 of Set 14 | terrace
# Processing Record 47 of Set 14 | oistins
# Processing Record 48 of Set 14 | lanzhou
# Processing Record 49 of Set 14 | zemio
# Processing Record 50 of Set 14 | yabrud
# Processing Record 1 of Set 15 | champerico
# Processing Record 2 of Set 15 | san policarpo
# Processing Record 3 of Set 15 | simao
# Processing Record 4 of Set 15 | addis abeba
# Processing Record 5 of Set 15 | berlevag
# Processing Record 6 of Set 15 | auki
# Processing Record 7 of Set 15 | dzhebariki-khaya
# Processing Record 8 of Set 15 | tucuma
# Processing Record 9 of Set 15 | inyonga
# Processing Record 10 of Set 15 | harlingen
# Processing Record 11 of Set 15 | krasnokamensk
# Processing Record 12 of Set 15 | ca mau
# Processing Record 13 of Set 15 | nisia floresta
# Processing Record 14 of Set 15 | churapcha
# Processing Record 15 of Set 15 | akyab
# Processing Record 16 of Set 15 | talaya
# Processing Record 17 of Set 15 | izhma
# Processing Record 18 of Set 15 | callaway
# Processing Record 19 of Set 15 | burica
# City not found. Skipping...
# Processing Record 20 of Set 15 | parrita
# Processing Record 21 of Set 15 | taungdwingyi
# Processing Record 22 of Set 15 | tarauaca
# Processing Record 23 of Set 15 | campos altos
# Processing Record 24 of Set 15 | saldanha
# Processing Record 25 of Set 15 | buala
# Processing Record 26 of Set 15 | gucheng
# Processing Record 27 of Set 15 | beira
# Processing Record 28 of Set 15 | tokur
# Processing Record 29 of Set 15 | okhotsk
# Processing Record 30 of Set 15 | sao lourenco do sul
# Processing Record 31 of Set 15 | sangar
# Processing Record 32 of Set 15 | coquimbo
# Processing Record 33 of Set 15 | kommunar
# Processing Record 34 of Set 15 | inhambane
# Processing Record 35 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 15 | boende
# Processing Record 37 of Set 15 | chiang kham
# Processing Record 38 of Set 15 | kargasok
# Processing Record 39 of Set 15 | panaba
# Processing Record 40 of Set 15 | minas
# Processing Record 41 of Set 15 | amargosa
# Processing Record 42 of Set 15 | sale
# Processing Record 43 of Set 15 | berbera
# Processing Record 44 of Set 15 | lanigan
# Processing Record 45 of Set 15 | chunoyar
# Processing Record 46 of Set 15 | katangli
# Processing Record 47 of Set 15 | farafangana
# Processing Record 48 of Set 15 | tyup
# Processing Record 49 of Set 15 | iroquois falls
# Processing Record 50 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 16 | kudahuvadhoo
# Processing Record 2 of Set 16 | lethem
# Processing Record 3 of Set 16 | krasnogorskoye
# Processing Record 4 of Set 16 | krutinka
# Processing Record 5 of Set 16 | chivilcoy
# Processing Record 6 of Set 16 | hwange
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Saskylakh  71.9167  114.0833    -24.77        98          11        8.68
# 1  Chokurdakh  70.6333  147.9167    -12.50        99         100        5.48
# 2   Esperance -33.8667  121.9000     63.18        67          83       16.91
# 3      Albany  42.6001  -73.9662     32.36        71          20        1.99
# 4       Vaini -21.2000 -175.2000     80.76        89          40        6.91
# 5   Manzhouli  49.6000  117.4333      9.99        60           1       13.69
# 6     Mataura -46.1927  168.8643     61.97        47          83        6.46
# 7  Nanortalik  60.1432  -45.2371     20.86        74           5       13.98
# 8      Atuona  -9.8000 -139.0333     77.74        75         100        9.10
# 9      Dingle  10.9995  122.6711     85.82        72          67       13.20
#
#   Country Current Description
# 0      RU          few clouds
# 1      RU     overcast clouds
# 2      AU       broken clouds
# 3      US          few clouds
# 4      TO    scattered clouds
# 5      CN           clear sky
# 6      NZ       broken clouds
# 7      GL           clear sky
# 8      PF     overcast clouds
# 9      PH       broken clouds

# %%
# Reorder the column order 
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saskylakh      RU  71.9167  114.0833    -24.77        98          11
# 1  Chokurdakh      RU  70.6333  147.9167    -12.50        99         100
# 2   Esperance      AU -33.8667  121.9000     63.18        67          83
# 3      Albany      US  42.6001  -73.9662     32.36        71          20
# 4       Vaini      TO -21.2000 -175.2000     80.76        89          40
# 5   Manzhouli      CN  49.6000  117.4333      9.99        60           1
# 6     Mataura      NZ -46.1927  168.8643     61.97        47          83
# 7  Nanortalik      GL  60.1432  -45.2371     20.86        74           5
# 8      Atuona      PF  -9.8000 -139.0333     77.74        75         100
# 9      Dingle      PH  10.9995  122.6711     85.82        72          67
#
#    Wind Speed Current Description
# 0        8.68          few clouds
# 1        5.48     overcast clouds
# 2       16.91       broken clouds
# 3        1.99          few clouds
# 4        6.91    scattered clouds
# 5       13.69           clear sky
# 6        6.46       broken clouds
# 7       13.98           clear sky
# 8        9.10     overcast clouds
# 9       13.20       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
